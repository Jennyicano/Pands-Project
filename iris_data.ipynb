# %% [markdown]
# # Iris Data set
#
# #### This notebook contains my analysis of the famous Iris dataset.
#
# #### Author Jennifer Ibanez Cano
#
# #### Student of Higher Diploma in Science in Data Analytics at the ATU Galway, 2024.
#
# #### Module Programming and Scripting
#
# I downloaded and saved in this repositary the dataset from [UCI Machine Learning Repository: Iris Data Set.](https://archive.ics.uci.edu/dataset/53/iris)
#
# ![Iris data](https://editor.analyticsvidhya.com/uploads/51518iris%20img1.png)

# %% [markdown]
# ### Libraries
#
# ***

# %%
# Data frames. 

import pandas as pd

# Plotting. 

import matplotlib.pyplot as plt

# Numerial arrays

import numpy as np

# Seaborn 

import seaborn as sns

# %% [markdown]
# ### Load data
#
# ***

# %%
# I loaded the data from the csv file in this repositary. 

# The data, it can be loaded too from the library of seaborn in GitHub:  df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

df = pd.read_csv('iris.data.csv')

# %%
# Have a look of the data. 

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Here in the data we can see there are 150 rows and 5 columns that provide different information of the flowers like species, sepal length, sepal width, petal length and petal width.

# %% [markdown]
# ### Inspect Data
#
# ***

# %%
# Check the different types of the variables. 

df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Checking the type of the 5 variables, we can see there are 4 variables of type float and 1 variable as object.
#
# After looking into the variable object, this one has the 3 types of the flower (Iris-setosa, Iris-versicolor, Iris-virginica) with the values of the other variables.

# %%
# Describe the data set
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Using the function describe(), it'll give us a description of the data which in this case contains: count, mean, std(standard deviation), minimum and maximum values.

# %% [markdown]
# As it's mentioned in the Analysis.py, there is a [summary text](https://github.com/Jennyicano/Pands-Project/blob/main/summary.txt) of each variable. In this summary we can see the different variables results in a text file. The code to create the sumary text file and add the results, it can be found in the [Analysis.py](https://github.com/Jennyicano/Pands-Project/blob/main/Analysis.py).

# %%
# The number of flowers per species. 

df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# We can see that this dataset is well balanced, all the species have the same number of data, 50.

# %% [markdown]
# For the following variables I'm using .groupby and the function mean to have the numbers in groups of different flowers and the mean of each variable.

# %%
# Check the petal width mean by species.

petal_w = df.groupby('species')['petal_width'].mean()
petal_w
# Out:
# species
# Iris-setosa        0.244
# Iris-versicolor    1.326
# Iris-virginica     2.026
# Name: petal_width, dtype: float64

# %% [markdown]
# The width of the petals of the Iris-setosa flowers is clearly shorter than the other two species.

# %%
# Check the petal length mean by specie.

petal_l = df.groupby('species')['petal_length'].mean()
petal_l
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %% [markdown]
# The length of the petals of the Iris-setosa flowers is clearly shorter than the other two species.

# %%
# Check the sepal width mean by specie.

sepal_w = df.groupby('species')['sepal_width'].mean()
sepal_w
# Out:
# species
# Iris-setosa        3.418
# Iris-versicolor    2.770
# Iris-virginica     2.974
# Name: sepal_width, dtype: float64

# %% [markdown]
# The width of the sepal of the Iris-setosa appears to be bigger than the other species.
#
# The width of the sepal between Iris-virginica and Iris-versicolor is quite similar.

# %%
# Check the sepal length mean by specie.

sepal_l = df.groupby('species')['sepal_length'].mean()
sepal_l
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %% [markdown]
# The sepal length of the Iris-setosa flowers is mainly shorter than the sepal length of the other species.
#
# There is less difference between the sepal length of the Iris-versicolor and the Iris-virginica.

# %% [markdown]
# ## Types of variables plot and histogram
#
# Below we can see the data applied in plots and histogram of the different variables.
#
# ***

# %%
# Histograms of each variale, the histograms will be saved to a png files. 

# Plotting the histogram of the diferent species. 

species = df['species']

plt.hist(species, bins=5, color='purple', edgecolor='black')
plt.xlabel('Species')
plt.ylabel('Quantity')
plt.title('Iris flowers')
plt.savefig('Species_hist.png')
plt.show()

# %%
# Plotting the histogram of the petal width. 

petal_w = df['petal_width']

plt.hist(petal_w, bins=10, color='blue', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Petal width (cm)')
plt.ylabel('')
plt.title('Petal width (cm) of Iris flowers')
plt.savefig('Petal width_hist.png')
plt.show()

# %%
# Plotting the histogram of the petal length. 

petal_l = df['petal_length']

plt.hist(petal_l, bins=10, color='green', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Petal Length (cm)')
plt.ylabel('')
plt.title('Petal length (cm) of Iris flowers')
plt.savefig('Petal length_hist.png')
plt.show()

# %%
# Plotting the histogram of the sepal width.

sepal_w = df['sepal_width']

plt.hist(sepal_w, bins=8, color='magenta', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Sepal width (cm)')
plt.ylabel('')
plt.title('Sepal width (cm) of Iris flowers')
plt.savefig('Sepal width_hist.png')
plt.show()

# %%
# Plotting the histogram of the sepal length. 

sepal_l = df['sepal_length']

plt.hist(sepal_l, bins=10, color='orange', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Sepal length (cm)')
plt.ylabel('')
plt.title('Sepal length (cm) of Iris flowers')
plt.savefig('Sepal length_hist.png')
plt.show()

# %%
# The first scatter plot is with the variables: petal length and petal width. 

# To start I'll get the data of the variables
species = df['species'].unique()
# unique() gets the unique elements of the array species, in this case the 3 types of Iris flowers.
petal_l = df['petal_length']
petal_w = df['petal_width']

# I'll asign diferent colors and shapes(using the format as markers) for the different species of Iris flowers, 
# to distinguish the differents between each others
colors = ['m', 'y', 'b']
markers = ['p', 's', 'D']

# I'm using the markers: 'p' as pentagon, 's' as square, , and 'D' as diamond shape.

# Create a scatter plot.
plt.figure(figsize=(10,7))
for i, species in enumerate(species):
    species = df[df['species'] == species]
    plt.scatter(species['petal_length'], species['petal_width'], color= colors[i], marker=markers[i], label=species, alpha=0.7)

# Axis labels.
plt.xlabel('Petal length (cm)' , color='pink')
plt.ylabel('Petal width (cm)', color='pink')

# Title.
plt.title('Scatter plot of petal length and petal widht by species', color='purple')
plt.legend(df['species'].unique())

# X limits.
plt.xlim(0, 8)
# Y limits.
plt.ylim(0, 3)

plt.savefig('Scatter plot of petal length and petal width.png')
plt.show()

# %% [markdown]
# After looking at this plot we can see that the length and width of the petal of the Iris-setosa flowers is clearly smaller than the other two species. Although the difference of the petal length is not very big between the Iris-versicolor and Iris-virginica, the length of versicolor flowers is mainly shorter than the virginica.
# Consequently, based on petal length, setosa is separable, while the other two species may overlap.

# %%
# The second scatter plot is with the variables: sepal length and sepal width. 

# To start I'll get the data of the variables that I'm using.
species = df['species'].unique()  
sepal_l = df['sepal_length']
sepal_w = df['sepal_width']

# I'll asign diferent colors and shapes(using thr formar as markers) for the different species of Iris flowers, 
# to distinguish the differents between each others
colors = ['m', 'y', 'b']
markers = ['v', 's', 'o']

# I'm using the markers: 'v' as triangle, 's' as square, and 'o' as a circle shape.

# Create a scatter plot.
plt.figure(figsize=(10,7))
for i, species in enumerate(species):
    species = df[df['species'] == species]
    plt.scatter(species['sepal_length'], species['sepal_width'], color= colors[i], marker=markers[i], label=species, alpha=0.7)

# Axis labels.
plt.xlabel('Sepal length (cm)', color='blue')
plt.ylabel('Sepal width (cm)', color='blue')

# Title.
plt.title('Scatter plot of sepal length and sepal width by species', color='green')
plt.legend(df['species'].unique())

# X limits.
plt.xlim(3, 9)
# Y limits.
plt.ylim(1, 5)

plt.savefig('Scatter plot of sepal length and sepal width.png')
plt.show()

# %% [markdown]
# Checking the result of this plot, the Iris-setosa flowers can be be easir to distingue it's sepal because is smaller than the other two species. Here we can see the same with the sepal as the petal in the Iris-versicolor and Iris-virginica, both of this species have similar size of sepal, here is the plot they are mixed and overlapping.

# %%
# Create a bar chart to show all the variables of each specie.

species = ("Iris-setosa", "Iris-versicolor", "Iris-virginica")
variables = {
    'petal_width': (0.244, 1.326, 2.026),
    'petal_length': (1.464, 4.260, 5.552),
    'sepal_width': (3.418, 2.770, 2.974), 
    'sepal_length': (5.006, 5.936, 6.588)
}
# The label locations.
x = np.arange(len(species)) 
# The width of the bars 
width = 0.15  
multiplier = 0

# To add the different variables of the Iris flowers I created multiple subplots using plt.subplots

fig, ax = plt.subplots(layout='constrained') 

for attribute, measurement in variables.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1
    
# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel('Measures (cm)')
ax.set_title('Iris Data')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 7)
plt.savefig('Bar chart Iris Data')
plt.show()

# %% [markdown]
# I created this bar chart to see clearly the details of each variable in the 3 specie.
#
# The Iris-virginica has the biggest sepal length, petal width and petal length. Being the biggest flower of the 3 species.
# The Iris-setosa has the biggest sepal width, and it looks the smaller one.
# The Iris-versicolor, it has a medium size and stay between the other 2.

# %% [markdown]
# ### Correlation coefficient.
#
# ***

# %% [markdown]
# I'll generate a correlation matrix with the numeric values to check which variables have the best corrleation between them.
# First I'll remove the non-numeric variables, because the non-numeric vakues are not useful for this analysis.
#
# Then I'll use the function corr()

# %%
df2 = df.drop('species', axis=1)

matrix = df2.corr()
print(matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# We can see from this matrix that the variables most correlated between them are petal length and petal width, with a strong positive correlation of 0.962757, as it's the correlation closer to 1 or -1.
#
# Here is another way to get the correlation coefficient between  variables.
#
# I'm using corrcoef() to get the correlation coeficient betweent 2 variables.

# %%
petal_l = df['petal_length']
petal_w = df['petal_width']
sepal_l = df['sepal_length']
sepal_w = df['sepal_width']


corr = np.corrcoef(petal_l, petal_w)
print(corr)

corr1 = np.corrcoef(sepal_l, sepal_w)
print(corr1)

corr2 = np.corrcoef(sepal_l, petal_l)
print(corr2)
# Out:
# [[1.        0.9627571]
#  [0.9627571 1.       ]]
# [[ 1.         -0.10936925]
#  [-0.10936925  1.        ]]
# [[1.         0.87175416]
#  [0.87175416 1.        ]]

# %% [markdown]
# ***
#
# ### End
